# %%
x = 10
y = 5

sum = x + y
sub = x - y
mul = x * y
div = x / y
mod = x % y

print(sum, sub, mul, div, mod)
# Out:
# 15 5 50 2.0 0

# %%
print("hello")
# Out:
# hello

# %%
x = 9
y = 9

greater_than = x > y
greater_than_equal = x >= y

less_than = x < y
less_than_equal = x <= y

print(greater_than, greater_than_equal, less_than, less_than_equal)
# Out:
# True True False False
