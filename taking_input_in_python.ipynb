# %%
name = input("What is your name? ")

print("Hello ", name);
# Out:
# Hello  Arif

# %%
age = input("What is your age")

age = int(age)

print(age, type(age));
# Out:
# 25 <class 'int'>

# %%
name = input("What is your name? ")
roll = int(input("What is your roll? "))
result = float(input("What is your result? "))

print("Hello " name, "Your roll is " roll, "and your result is " result)
# Out:
#   Cell In[11], line 5
#     print("Hello " name "Your roll is " roll "and your result is " result)
#                    ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?
