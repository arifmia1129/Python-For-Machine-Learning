# %%
is_raining = False;

if(is_raining):
    print("You should carry a rain coat");
    print("Shouldn't go outside today without important works");
else:
    print("It's a sunny day");
    print("Enjoy outside today");
# Out:
# It's a sunny day
# Enjoy outside today

# %%
my_balance = 100;
weather_condition_good = True;

if(my_balance > 500):
   if(weather_condition_good):
      print("Go to restaurant with family");
   else:
      print("I go only and bring food to home");
else:
   print("Should order something in online within my budget");
# Out:
# Go to restaurant with family
