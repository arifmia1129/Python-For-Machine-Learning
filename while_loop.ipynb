# %%
count = 1;

while count < 10:
    print("Hello world");
    count = count + 1;
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
